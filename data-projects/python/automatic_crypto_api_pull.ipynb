# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0971d33c8e6e4178bf335278af7db483',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(json.dumps(data, indent=2)[:1000])
    
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {
#   "status": {
#     "timestamp": "2026-03-03T07:33:55.370Z",
#     "error_code": 0,
#     "error_message": null,
#     "elapsed": 122,
#     "credit_count": 25,
#     "notice": null,
#     "total_count": 8710
#   },
#   "data": [
#     {
#       "id": 1,
#       "name": "Bitcoin",
#       "symbol": "BTC",
#       "slug": "bitcoin",
#       "num_market_pairs": 12570,
#       "date_added": "2010-07-13T00:00:00.000Z",
#       "tags": [
#         "mineable",
#         "pow",
#         "sha-256",
#         "store-of-value",
#         "state-channel",
#         "coinbase-ventures-portfolio",
#         "three-arrows-capital-portfolio",
#         "polychain-capital-portfolio",
#         "binance-labs-portfolio",
#         "blockchain-capital-portfolio",
#         "boostvc-portfolio",
#         "cms-holdings-portfolio",
#         "dcg-portfolio",
#         "dragonfly-capital-portfolio",
#         "electric-capital-portfolio",
#         "fabric-ventures-portfolio",
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#          id                   name  symbol                slug  \
# 0         1                Bitcoin     BTC             bitcoin
# 1      1027               Ethereum     ETH            ethereum
# 2       825            Tether USDt    USDT              tether
# 3      1839                    BNB     BNB                 bnb
# 4        52                    XRP     XRP                 xrp
# ...     ...                    ...     ...                 ...
# 4995  34281          exSat Network    XSAT       exsat-network
# 4996  31145                 Source  SOURCE              source
# 4997  31424                Evrmore     EVR             evrmore
# 4998  32309  Bretta (Brett’s Wife)  BRETTA  bretta-bretts-wife
# 4999  27771          CruxDecussata       X           x-com-erc
#
#       num_market_pairs                date_added  \
# 0                12570  2010-07-13T00:00:00.000Z
# 1                11604  2015-08-07T00:00:00.000Z
# 2               172276  2015-02-25T00:00:00.000Z
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0971d33c8e6e4178bf335278af7db483',
    }
    
    session = Session()
    session.headers.update(headers)
    
    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(json.dumps(data, indent=2)[:1000])
        
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
        
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df 

    if not os.path.isfile(r'C:\Users\Casa\Desktop\Data_Analysis\python\API.csv'):
        df.to_csv(r'C:\Users\Casa\Desktop\Data_Analysis\python\API.csv', header = 'column_names')
    else:
        df.to_csv(r'C:\Users\Casa\Desktop\Data_Analysis\python\API.csv', mode = 'a', header = False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# {
#   "status": {
#     "timestamp": "2026-03-03T07:46:23.933Z",
#     "error_code": 0,
#     "error_message": null,
#     "elapsed": 628,
#     "credit_count": 25,
#     "notice": null,
#     "total_count": 8710
#   },
#   "data": [
#     {
#       "id": 1,
#       "name": "Bitcoin",
#       "symbol": "BTC",
#       "slug": "bitcoin",
#       "num_market_pairs": 12570,
#       "date_added": "2010-07-13T00:00:00.000Z",
#       "tags": [
#         "mineable",
#         "pow",
#         "sha-256",
#         "store-of-value",
#         "state-channel",
#         "coinbase-ventures-portfolio",
#         "three-arrows-capital-portfolio",
#         "polychain-capital-portfolio",
#         "binance-labs-portfolio",
#         "blockchain-capital-portfolio",
#         "boostvc-portfolio",
#         "cms-holdings-portfolio",
#         "dcg-portfolio",
#         "dragonfly-capital-portfolio",
#         "electric-capital-portfolio",
#         "fabric-ventures-portfolio",
# ...
